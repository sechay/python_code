# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/naveen/Documents/python_code/MSFI/CreditCard.xls','Data',header = [1])

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df1 = df[['ID','LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
       'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
       'default payment next month']]
df1.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'PAY_AMT1', 'PAY_AMT2',
#        'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df2 = df1.rename(columns={'PAY_0': 'RS_0', 'PAY_2': 'RS_2', 'PAY_3': 'RS_3', 'PAY_4': 'RS_4', 'PAY_5': 'RS_5', 'PAY_6': 'RS_6'})

# %%
df2.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'RS_0',
#        'RS_2', 'RS_3', 'RS_4', 'RS_5', 'RS_6', 'PAY_AMT1', 'PAY_AMT2',
#        'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
#df2.to_excel('/Users/naveen/Documents/python_code/MSFI/CreditCard_clean.xls',sheet_name='Data')
df2.to_csv("/Users/naveen/Documents/python_code/MSFI/CreditCard_clean.csv", index=False)

# %%
df1.groupby(['PAY_AMT1']).size().reset_index(name='Count')
# Out:
#       PAY_AMT1  Count
# 0            0   5249
# 1            1      9
# 2            2     14
# 3            3     15
# 4            4     18
# 5            5     12
# 6            6     15
# 7            7      9
# 8            8      8
# 9            9      7
# 10          10     10
# 11          11      4
# 12          12      6
# 13          13      7
# 14          14      7
# 15          15      5
# 16          16      3
# 17          17      6
# 18          18      2
# 19          20      4
# 20          21      1
# 21          22      5
# 22          23      2
# 23          24      2
# 24          25      3
# 25          26      3
# 26          27      2
# 27          28      3
# 28          29      1
# 29          31      3
# ...        ...    ...
# 7913    232557      1
# 7914    234000      1
# 7915    235728      1
# 7916    236533      1
# 7917    237000      1
# 7918    238861      1
# 7919    239104      1
# 7920    240101      1
# 7921    242247      1
# ...

# %%
df.groupby(['SEX']).size().reset_index(name='Count')
# Out:
#    SEX  Count
# 0    1  11888
# 1    2  18112

# %%
df.groupby(['EDUCATION']).size().reset_index(name='Count')
# Out:
#    EDUCATION  Count
# 0          0     14
# 1          1  10585
# 2          2  14030
# 3          3   4917
# 4          4    123
# 5          5    280
# 6          6     51

# %%
df.groupby(['default payment next month']).size().reset_index(name='Count')
# Out:
#    default payment next month  Count
# 0                           0  23364
# 1                           1   6636
