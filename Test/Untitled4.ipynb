# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/naveen/Documents/Makeover_Mondays/MakeoverMonday_310.xls')

# %%
df1= df.transpose()

# %%
df1.head()
# Out:
#                                                         0    \
# Country Name                                        Armenia
# Country Code                                            ARM
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 1.34446
#
#                                                         1    \
# Country Name                                     Azerbaijan
# Country Code                                            AZE
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 4.18406
#
#                                                         2    \
# Country Name                         Bosnia and Herzegovina
# Country Code                                            BIH
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 3.97154
#
#                                                         3    \
# Country Name                                        Belarus
# Country Code                                            BLR
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                  6.2831
#
#                                                         4    \
# Country Name                                 Czech Republic
# Country Code                                            CZE
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 11.4461
#
#                                                                5    \
# Country Name         Europe & Central Asia (excluding high income)
# Country Code                                                   ECA
# Indicator Name              CO2 emissions (metric tons per capita)
# Indicator Code                                      EN.ATM.CO2E.PC
# average_per_country                                        7.51252
#
#                                                         6    \
# Country Name                          Europe & Central Asia
# Country Code                                            ECS
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 7.76405
#
#                                                         7    \
# Country Name                                        Estonia
# Country Code                                            EST
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 12.7589
#
#                                                         8    \
# Country Name                          Micronesia, Fed. Sts.
# Country Code                                            FSM
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 1.19242
#
#                                                         9    \
# Country Name                                        Georgia
# Country Code                                            GEO
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 1.48408
#
#                                       ...                    \
# Country Name                          ...
# Country Code                          ...
# Indicator Name                        ...
# Indicator Code                        ...
# average_per_country                   ...
#
#                                                         232  \
# Country Name                            Upper middle income
# Country Code                                            UMC
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 3.30291
#
#                                                         233  \
# Country Name                                        Uruguay
# Country Code                                            URY
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 1.76953
#
#                                                         234  \
# Country Name                                  United States
# Country Code                                            USA
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 19.1349
#
#                                                         235  \
# Country Name                 St. Vincent and the Grenadines
# Country Code                                            VCT
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                0.938539
#
#                                                         236  \
# Country Name                                  Venezuela, RB
# Country Code                                            VEN
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 5.95181
#
#                                                         237  \
# Country Name                                        Vietnam
# Country Code                                            VNM
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                0.632748
#
#                                                         238  \
# Country Name                                          World
# Country Code                                            WLD
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                 4.12755
#
#                                                         239  \
# Country Name                                          Samoa
# Country Code                                            WSM
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                0.613257
#
#                                                         240  \
# Country Name                                    Yemen, Rep.
# Country Code                                            YEM
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                0.719367
#
#                                                         241
# Country Name                                   South Africa
# Country Code                                            ZAF
# Indicator Name       CO2 emissions (metric tons per capita)
# Indicator Code                               EN.ATM.CO2E.PC
# average_per_country                                  7.9918
#
# [5 rows x 242 columns]

# %%
df2=df1.rename(columns=df1.iloc[0]).drop(df1.index[0])

# %%
df2.to_excel('/Users/naveen/Documents/Makeover_Mondays/MakeoverMonday_3105.xls',sheet_name='Data')
