# %%
import mysql.connector as msq
import pandas as pd
import numpy as np
import sqlalchemy as sql
#from google.cloud import bigquery

# %%
import urllib
url = "https://data.gov.sg/api/action/datastore_search?resource_id=f7bbdc43-c568-4e60-9afa-b77ba5a14aa0&limit=5"
fileobj=urllib.urlopen(url)
print fileobj.read()
# Out:
#   File "<ipython-input-15-a55b794f2016>", line 4
#     print fileobj.read()
#                 ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv("/Users/naveen/Documents/python_code/Test/dataset-Sg/singapore-citizens.csv")

# %%
df.columns
# Out:
# Index(['year', 'level_1', 'level_2', 'value'], dtype='object')

# %%
database_connection = sql.create_engine('mysql+pymysql://naveen:naveen@192.168.0.112:3307/NAVEEN')
df.to_sql(con=database_connection, name='sg_citizen', if_exists='replace')

# %%
connection = msq.connect(host = '192.168.0.112',
                         port = '3307',                    
                       user = 'naveen',
                       password = 'naveen',
                        database = 'NAVEEN')
cursor = connection.cursor()
cursor.execute("select * from sg_citizen")
myresult = cursor.fetchall()
for x in myresult:
    print(x)
connection.close()
# Out:
# (0, 1970, 'Total Citizen', '0  -  4 Years', '226454')
# (1, 1970, 'Total Citizen', '5  -  9 Years', '267122')
# (2, 1970, 'Total Citizen', '10 - 14 Years', '273014')
# (3, 1970, 'Total Citizen', '15 - 19 Years', '227001')
# (4, 1970, 'Total Citizen', '20 - 24 Years', '175775')
# (5, 1970, 'Total Citizen', '25 - 29 Years', '102974')
# (6, 1970, 'Total Citizen', '30 - 34 Years', '112188')
# (7, 1970, 'Total Citizen', '35 - 39 Years', '99402')
# (8, 1970, 'Total Citizen', '40 - 44 Years', '89503')
# (9, 1970, 'Total Citizen', '45 - 49 Years', '72546')
# (10, 1970, 'Total Citizen', '50 - 54 Years', '64000')
# (11, 1970, 'Total Citizen', '55 - 59 Years', '59360')
# (12, 1970, 'Total Citizen', '60 - 64 Years', '44625')
# (13, 1970, 'Total Citizen', '65 - 69 Years', '30228')
# (14, 1970, 'Total Citizen', '70 - 74 Years', '16534')
# (15, 1970, 'Total Citizen', '75 - 79 Years', '8614')
# (16, 1970, 'Total Citizen', '80 - 84 Years', 'na')
# ...

# %%
df = pd.read_gbq("select * from sg_citizen.sg_citizen", project_id="My First Project")
# Out:
# ---------------------------------------------------------------------------
# DistributionNotFound                      Traceback (most recent call last)
# <ipython-input-11-fee2b5d68089> in <module>()
# ----> 1 df = pd.read_gbq("select * from sg_citizen.sg_citizen", project_id="My First Project")
#
# /anaconda3/envs/test1/lib/python3.4/site-packages/pandas/io/gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, verbose, private_key, dialect)
#     698     connector = GbqConnector(project_id, reauth=reauth, verbose=verbose,
#     699                              private_key=private_key,
# --> 700                              dialect=dialect)
#     701     schema, pages = connector.run_query(query)
#     702     dataframe_list = []
#
# /anaconda3/envs/test1/lib/python3.4/site-packages/pandas/io/gbq.py in __init__(self, project_id, reauth, verbose, private_key, dialect)
#     147     def __init__(self, project_id, reauth=False, verbose=False,
# ...
