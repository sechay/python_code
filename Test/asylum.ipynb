# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/naveen/Documents/Makeover_Mondays/asylum.csv")

# %%
df.columns
# Out:
# Index(['GEO/TIME', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018'],
#       dtype='object')

# %%
df1= df.transpose()

# %%
df1.head()
# Out:
#                                      0        1         2        3        4   \
# GEO/TIME  European Union - 28 countries  Belgium  Bulgaria  Czechia  Denmark
# 2009                            263,835   21,615       855    1,235    3,720
# 2010                            259,630   26,080     1,025      775    5,065
# 2011                            309,040   31,910       890      750    3,945
# 2012                            335,290   28,075     1,385      740    6,045
#
#                                                         5        6        7   \
# GEO/TIME  Germany (until 1990 former territory of the FRG)  Estonia  Ireland
# 2009                                                32,910       40    2,680
# 2010                                                48,475       35    1,935
# 2011                                                53,235       65    1,290
# 2012                                                77,485       75      955
#
# ...

# %%
df1.to_excel('/Users/naveen/Documents/Makeover_Mondays/MakeoverMonday_asylum.xls',sheet_name='Data')
